# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
fig, ax = plt.subplots() #utiliser plt qu'une suele fois, un seul dessin, un objet 
x = np.linspace(norm.ppf(0.01),
                norm.ppf(0.99), 100) #génère 100 point en min et max donné

ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.6)

#ax.plot(x, np.full(len(x), 0.2),
#      'b-', lw=1)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas 

df = pandas.read_csv("data/TCL_wt1.tsv",sep='\t')
df = df.dropna()
df.describe()
# Out:
#        Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)
# count                                       1.746000e+03
# mean                                        8.234275e-01
# std                                         3.509350e-01
# min                                         1.034030e-08
# 25%                                         1.000000e+00
# 50%                                         1.000000e+00
# 75%                                         1.000000e+00
# max                                         1.000000e+00

# %%
df = df.astype({'Log2 Corrected Abundance Ratio': float,'-LOG10 Adj.P-val': float } )
df.dtypes
# Out:
# Accession                                                        object
# Description                                                      object
# Gene Symbol                                                      object
# Corrected Abundance ratio (1.53)                                 object
# Log2 Corrected Abundance Ratio                                  float64
# Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)    float64
# -LOG10 Adj.P-val                                                float64
# dtype: object

# %%
df.iloc[:5,:]
df.iloc[:5,[0,1,2,3]]
df.iloc[:,[-1]]
# Out:
#      -LOG10 Adj.P-val
# 0         4.260067469
# 1          3.45462743
# 2         4.571899347
# 4         1.699767669
# 5         1.434786589
# ...               ...
# 2011      0.507623276
# 2016      1.873756665
# 2020      2.652390664
# 2021       4.16495627
# 2022      1.444561032
#
# [1746 rows x 1 columns]

# %%
df.dtypes
df.loc[(df['-LOG10 Adj.P-val'] > 0 ) & (df['Log2 Corrected Abundance Ratio'] > 0.0 ) ]
# Out:
#      Accession                                        Description  \
# 1938    P68919  50S ribosomal protein L25 OS=Escherichia coli ...
# 1939    P0ACG1  DNA-binding protein StpA OS=Escherichia coli (...
# 1940    P0A903  Outer membrane protein assembly factor BamC OS...
# 1945    P0ADE4  Translocation and assembly module subunit TamA...
# 1946    P02943  Maltoporin OS=Escherichia coli (strain K12) OX...
# 1947    P77774  Outer membrane protein assembly factor BamB OS...
# 1948    P0A940  Outer membrane protein assembly factor BamA OS...
# 1955    P0AEQ1  Protein GlcG OS=Escherichia coli (strain K12) ...
# 1957    P09169  Protease 7 OS=Escherichia coli (strain K12) OX...
# 1962    P05825  Ferrienterobactin receptor OS=Escherichia coli...
# 1967    P39180  Antigen 43 OS=Escherichia coli (strain K12) OX...
# 1968    P0ACF8  DNA-binding protein H-NS OS=Escherichia coli (...
# 1969    P0A7K2  50S ribosomal protein L7/L12 OS=Escherichia co...
# ...

# %%
fig, ax = plt.subplots() #utiliser plt qu'une suele fois, un seul dessin, un objet 
x = df['Log2 Corrected Abundance Ratio']

ax.hist(x, 20)

ax.set_xlabel('Log2 Corrected Abundance Ratio')
ax.set_ylabel('protein count')

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy
import math 
mean=numpy.mean(df['Log2 Corrected Abundance Ratio'])
ec=numpy.std(df['Log2 Corrected Abundance Ratio'])*numpy.std(df['Log2 Corrected Abundance Ratio'])
n=len(df['Log2 Corrected Abundance Ratio'])
ec_corrigée=math.sqrt((n/(n+1))*ec)
print(ec_corrigée)

fig, ax = plt.subplots() #utiliser plt qu'une suele fois, un seul dessin, un objet 
#x = df['Log2 Corrected Abundance Ratio']
x = df['Log2 Corrected Abundance Ratio']
hist = ax.hist(x, 50)
dx=hist[1][1] - hist[1][0]
scale = len(x)*dx

ax.set_xlabel('Log2 Corrected Abundance Ratio')
ax.set_ylabel('protein count')

x = np.linspace(-4, 1.5, 100)
ax.plot(x, norm.pdf(x,mean,ec_corrigée)*scale)


fig.savefig("hist_norm.png")
# Out:
# 0.4704898017787741
# <img src="data:image/png;base64,..." width="640">
